# %%
import os
import pandas as pd

# %%
base_path = '/Users/erika_ishizuka/Desktop/python_final_project'
vax_file = 'who_vax.csv'
em_yr_file = 'excess_yr.csv'
em_sex_file = 'excess_sex_age.csv'
em_mon_file = 'excess_yr_month.csv'
death_rate_file = 'crude_death.csv'

vax = pd.read_csv(os.path.join(base_path, vax_file))
em_yr = pd.read_csv(os.path.join(base_path, em_yr_file), skiprows=8)
em_sex = pd.read_csv(os.path.join(base_path, em_sex_file), skiprows=11)
em_mon = pd.read_csv(os.path.join(base_path, em_mon_file), skiprows=12)
crude_death = pd.read_csv(os.path.join(base_path, death_rate_file))

# %%
sa_iso = ['ARG', 'BOL', 'BRA', 'CHL', 'COL', 'ECU', 'GUY', 'PER', 'PRY', 'SUR', 'URY', 'VEN']

# %%
vax_cols = ['PRODUCT_NAME', 'COMPANY_NAME', 'AUTHORIZATION_DATE', 'END_DATE', 'COMMENT', 'DATA_SOURCE']
vax = vax.loc[vax['ISO3'].isin(sa_iso)].drop(vax_cols, axis=1).dropna()
vax = vax.rename(columns={'VACCINE_NAME': 'vaccine', 'START_DATE': 'start date', 'ISO3': 'iso3'})
vax['year'] = pd.DatetimeIndex(vax['start date']).year
vax
# Out:
#      iso3                      vaccine start date  year
# 47    PRY     Gamaleya - Gam-Covid-Vac    2/22/21  2021
# 48    ARG     Gamaleya - Gam-Covid-Vac   12/29/20  2020
# 49    BOL     Gamaleya - Gam-Covid-Vac    1/30/21  2021
# 60    VEN     Gamaleya - Gam-Covid-Vac    2/22/21  2021
# 79    GUY     Gamaleya - Gam-Covid-Vac     4/2/21  2021
# 134   VEN    Beijing CNBG - BBIBP-CorV     3/8/21  2021
# 135   PER    Beijing CNBG - BBIBP-CorV     2/9/21  2021
# 153   BOL    Beijing CNBG - BBIBP-CorV     5/2/21  2021
# 155   PRY    Beijing CNBG - BBIBP-CorV    3/15/21  2021
# 159   ARG    Beijing CNBG - BBIBP-CorV     3/2/21  2021
# 160   GUY    Beijing CNBG - BBIBP-CorV     3/2/21  2021
# 201   SUR    Beijing CNBG - BBIBP-CorV    7/10/21  2021
# 263   BOL      AstraZeneca - Vaxzevria    3/22/21  2021
# 279   PRY      AstraZeneca - Vaxzevria    3/23/21  2021
# 296   URY      AstraZeneca - Vaxzevria    4/17/21  2021
# 297   ECU      AstraZeneca - Vaxzevria    3/19/21  2021
# 307   ARG      AstraZeneca - Vaxzevria    3/30/21  2021
# 309   SUR      AstraZeneca - Vaxzevria    5/26/21  2021
# 317   COL      AstraZeneca - Vaxzevria    3/29/21  2021
# 325   BRA      AstraZeneca - Vaxzevria    1/18/21  2021
# 331   PER      AstraZeneca - Vaxzevria    4/21/21  2021
# 347   CHL      AstraZeneca - Vaxzevria    4/27/21  2021
# 349   CHL         CanSino - Convidecia     6/3/21  2021
# 357   ECU         CanSino - Convidecia     8/2/21  2021
# 358   ARG         CanSino - Convidecia     9/8/21  2021
# 387   SUR  Pfizer BioNTech - Comirnaty    8/28/21  2021
# 388   ARG  Pfizer BioNTech - Comirnaty    9/16/21  2021
# 394   GUY  Pfizer BioNTech - Comirnaty    8/24/21  2021
# 450   COL  Pfizer BioNTech - Comirnaty    2/17/21  2021
# 456   CHL  Pfizer BioNTech - Comirnaty   12/21/20  2020
# 465   ECU  Pfizer BioNTech - Comirnaty    1/20/21  2021
# 501   URY  Pfizer BioNTech - Comirnaty    3/12/21  2021
# 505   PER  Pfizer BioNTech - Comirnaty     3/8/21  2021
# 529   BRA  Pfizer BioNTech - Comirnaty     5/3/21  2021
# 536   BOL  Pfizer BioNTech - Comirnaty    4/30/21  2021
# 541   PRY  Pfizer BioNTech - Comirnaty    7/12/21  2021
# 546   PRY           Moderna - Spikevax     6/9/21  2021
# 552   SUR           Moderna - Spikevax    7/27/21  2021
# 555   ARG           Moderna - Spikevax     8/2/21  2021
# 557   COL           Moderna - Spikevax    7/27/21  2021
# 564   GUY           Moderna - Spikevax     7/3/21  2021
# 609   CHL           Moderna - Spikevax     2/2/22  2022
# 615   BOL           Moderna - Spikevax    1/10/22  2022
# 671   PRY             Bharat - Covaxin    4/10/21  2021
# 705   BRA       Janssen - Ad26.COV 2-S    6/23/21  2021
# 805   BOL       Janssen - Ad26.COV 2-S    10/7/21  2021
# 822   COL       Janssen - Ad26.COV 2-S    6/23/21  2021
# 832   CHL          Sinovac - CoronaVac     2/3/21  2021
# 833   BRA          Sinovac - CoronaVac    1/17/21  2021
# 836   COL          Sinovac - CoronaVac    2/22/21  2021
# 837   ECU          Sinovac - CoronaVac     3/8/21  2021
# 847   URY          Sinovac - CoronaVac    2/27/21  2021
# 851   PRY          Sinovac - CoronaVac    3/10/21  2021
# 936   GUY             SII - Covishield    2/11/21  2021
# 971   SUR             SII - Covishield    2/23/21  2021
# 974   ARG             SII - Covishield    2/21/21  2021
# 975   BRA             SII - Covishield    1/17/21  2021
# 1039  PRY          Julphar - Hayat-Vax    5/24/21  2021

# %%
em_yr_cols = ['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'excess.low', 'excess.high']
em_yr = em_yr.loc[em_yr['iso3'].isin(sa_iso)].drop(em_yr_cols, axis=1)
em_yr = em_yr.rename(columns={'pop.e5': 'population', 'excess.mean': 'excess mean'})
em_yr = em_yr[em_yr['year'].str.contains('2020-2021')==False]
em_yr
# Out:
#                                 Country iso3  year  population  excess mean
# 18                            Argentina  ARG  2020       452.0         70.0
# 19                            Argentina  ARG  2021       456.1        128.0
# 60     Bolivia (Plurinational State of)  BOL  2020       116.7        311.0
# 61     Bolivia (Plurinational State of)  BOL  2021       118.3        437.0
# 69                               Brazil  BRA  2020      2125.6         99.0
# 70                               Brazil  BRA  2021      2139.9        220.0
# 102                               Chile  CHL  2020       191.2         76.0
# 103                               Chile  CHL  2021       192.1        126.0
# 108                            Colombia  COL  2020       508.8        106.0
# 109                            Colombia  COL  2021       512.7        216.0
# 156                             Ecuador  ECU  2020       176.4        263.0
# 157                             Ecuador  ECU  2021       178.9        193.0
# 219                              Guyana  GUY  2020         7.9         50.0
# 220                              Guyana  GUY  2021         7.9        306.0
# 402                            Paraguay  PRY  2020        71.3         34.0
# 403                            Paraguay  PRY  2021        72.2        241.0
# 405                                Peru  PER  2020       329.7        406.0
# 406                                Peru  PER  2021       333.6        467.0
# 498                            Suriname  SUR  2020         5.9        -49.0
# 499                            Suriname  SUR  2021         5.9        171.0
# 558                             Uruguay  URY  2020        34.7        -65.0
# 559                             Uruguay  URY  2021        34.9        154.0
# 567  Venezuela (Bolivarian Republic of)  VEN  2020       284.4         13.0
# 568  Venezuela (Bolivarian Republic of)  VEN  2021       287.0         65.0

# %%
em_sex_cols=['Nx', 'expected.mean', 'acm.mean', 'type']
em_sex = em_sex.loc[em_sex['iso3'].isin(sa_iso)].drop(em_sex_cols, 
                                                      axis=1).rename(columns={'excess.mean': 'excess mean'})
em_sex
# Out:
#                                  country iso3    year     sex       age  \
# 140                            Argentina  ARG  2020.0  Female   0 to 24
# 141                            Argentina  ARG  2020.0  Female  25 to 39
# 142                            Argentina  ARG  2020.0  Female  40 to 49
# 143                            Argentina  ARG  2020.0  Female  50 to 59
# 144                            Argentina  ARG  2020.0  Female  60 to 69
# ...                                  ...  ...     ...     ...       ...
# 5231  Venezuela (Bolivarian Republic of)  VEN  2021.0    Male  40 to 49
# 5232  Venezuela (Bolivarian Republic of)  VEN  2021.0    Male  50 to 59
# 5233  Venezuela (Bolivarian Republic of)  VEN  2021.0    Male  60 to 69
# 5234  Venezuela (Bolivarian Republic of)  VEN  2021.0    Male  70 to 79
# 5235  Venezuela (Bolivarian Republic of)  VEN  2021.0    Male   80 plus
#
#       excess mean
# 140           0.0
# 141         166.0
# 142         114.0
# 143         188.0
# 144        1739.0
# ...           ...
# 5231        168.0
# 5232       1441.0
# 5233       3370.0
# 5234       3388.0
# 5235       3061.0
#
# [336 rows x 6 columns]

# %%
em_mon_cols = ['type', 'expected.mean', 'acm.mean', 'cumul.excess.mean', 'cumul.excess.low', 'cumul.excess.high']
em_mon = em_mon.drop(em_mon_cols, axis=1).dropna()
em_mon = em_mon.loc[em_mon['iso3'].isin(sa_iso)]
em_mon
# Out:
#                                  country iso3    year  month  excess.mean
# 120                            Argentina  ARG  2020.0    1.0       -207.0
# 121                            Argentina  ARG  2020.0    2.0      -1106.0
# 122                            Argentina  ARG  2020.0    3.0       -442.0
# 123                            Argentina  ARG  2020.0    4.0      -2274.0
# 124                            Argentina  ARG  2020.0    5.0      -2765.0
# ...                                  ...  ...     ...    ...          ...
# 4483  Venezuela (Bolivarian Republic of)  VEN  2021.0    8.0       1843.0
# 4484  Venezuela (Bolivarian Republic of)  VEN  2021.0    9.0       1581.0
# 4485  Venezuela (Bolivarian Republic of)  VEN  2021.0   10.0       1171.0
# 4486  Venezuela (Bolivarian Republic of)  VEN  2021.0   11.0        915.0
# 4487  Venezuela (Bolivarian Republic of)  VEN  2021.0   12.0        777.0
#
# [288 rows x 5 columns]

# %%
merge1 = vax.merge(em_yr, how='outer', on='iso3')
merge1
# Out:
#     iso3                      vaccine start date   Country  year  population  \
# 0    PRY     Gamaleya - Gam-Covid-Vac    2/22/21  Paraguay  2020        71.3
# 1    PRY     Gamaleya - Gam-Covid-Vac    2/22/21  Paraguay  2021        72.2
# 2    PRY    Beijing CNBG - BBIBP-CorV    3/15/21  Paraguay  2020        71.3
# 3    PRY    Beijing CNBG - BBIBP-CorV    3/15/21  Paraguay  2021        72.2
# 4    PRY      AstraZeneca - Vaxzevria    3/23/21  Paraguay  2020        71.3
# ..   ...                          ...        ...       ...   ...         ...
# 111  CHL  Pfizer BioNTech - Comirnaty   12/21/20     Chile  2021       192.1
# 112  CHL           Moderna - Spikevax     2/2/22     Chile  2020       191.2
# 113  CHL           Moderna - Spikevax     2/2/22     Chile  2021       192.1
# 114  CHL          Sinovac - CoronaVac     2/3/21     Chile  2020       191.2
# 115  CHL          Sinovac - CoronaVac     2/3/21     Chile  2021       192.1
#
#      excess mean
# 0           34.0
# 1          241.0
# 2           34.0
# 3          241.0
# 4           34.0
# ..           ...
# 111        126.0
# 112         76.0
# 113        126.0
# 114         76.0
# 115        126.0
#
# [116 rows x 7 columns]
